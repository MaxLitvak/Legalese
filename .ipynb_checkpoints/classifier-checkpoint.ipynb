# %%
# load data

import json

data = None
with open('./classifier_data.json') as file :
    data = json.load(file)

allChunks = list()
for policy in data :
    allChunks.extend(policy['chunks'])
    
labels = None
with open('./labels.json') as file :
    labels = json.load(file)

# %%
# logistic regression classifier

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

def logisticRegression(labelName, data, printRes) :
    df = pd.DataFrame(data)
    if labelName == 'important' :
        df['important'] = df['important'].map({ True: 1, False: 0 })
    
    X = df['text']
    y = df[labelName]

    vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
    X_tfidf = vectorizer.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

    model = LogisticRegression()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    if printRes :
        print(f'Classification Report for {labelName}:')
        print(classification_report(y_test, y_pred))
        print(f'Accuracy: {accuracy_score(y_test, y_pred):.2f}')
    
    return model

logisticRegression('important', allChunks, True)
print('\n-----------------------------------------------------------\n')
logisticRegression('label', allChunks, True)
# Out:
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90       528
#            1       0.74      0.48      0.58       164
#
#     accuracy                           0.84       692
#    macro avg       0.80      0.71      0.74       692
# weighted avg       0.83      0.84      0.82       692
#
# Accuracy: 0.84
#
# -----------------------------------------------------------
#
# Classification Report for label:
#                              precision    recall  f1-score   support
#
#                 Advertising       0.69      0.60      0.64        15
#           Children's policy       1.00      0.88      0.93         8
#                     Contact       0.68      0.62      0.65        21
#                     Cookies       0.65      0.81      0.72        21
#      Data in other counries       0.75      0.35      0.48        17
#              Data retention       0.81      0.76      0.79        17
#                 Data rights       0.72      0.77      0.75        75
#               Data security       0.65      0.65      0.65        17
#                Data sharing       0.56      0.47      0.51        30
#                    Data use       0.56      0.59      0.57        46
#                Do not track       0.00      0.00      0.00         1
#                         End       0.00      0.00      0.00        15
#                 Full policy       0.00      0.00      0.00         1
#                       Intro       0.39      0.33      0.36        21
# Legality of data processing       0.80      0.71      0.75        28
#      Location of processing       1.00      0.40      0.57         5
#                Modification       0.92      0.86      0.89        14
#                  Newsletter       1.00      0.50      0.67         2
#                       Other       0.53      0.64      0.58        97
#       Other data collection       0.67      0.27      0.38        30
#               Personal data       0.48      0.68      0.56        53
#                      Random       0.72      0.93      0.81        80
#                         TOC       0.00      0.00      0.00         1
#           Third party sites       0.69      0.77      0.73        44
#                Website data       0.89      0.53      0.67        30
#                      emails       0.00      0.00      0.00         3
#
#                    accuracy                           0.65       692
#                   macro avg       0.58      0.50      0.53       692
#                weighted avg       0.64      0.65      0.63       692
#
# Accuracy: 0.65
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# LogisticRegression()

# %%
chunksByLabel = dict()
for label in labels :
    chunksByLabel[label] = list()
for policy in data :
    for chunk in policy['chunks'] :
        chunksByLabel[chunk['label']].append(chunk)

importanceModels = dict()
for label, chunks in chunksByLabel.items() :
    print(label)
    print(len(chunks))
    try :
        models[label] = logisticRegression('important', chunks, True)
    except :
        print('error')
    print('\n-----------------------------------------------------------\n')
# Out:
# Intro
# 131
# error
#
# -----------------------------------------------------------
#
# TOC
# 13
# error
#
# -----------------------------------------------------------
#
# Modification
# 72
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.93        15
#    macro avg       0.47      0.50      0.48        15
# weighted avg       0.87      0.93      0.90        15
#
# Accuracy: 0.93
#
# -----------------------------------------------------------
#
# Personal data
# 320
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.94      0.58      0.71        26
#            1       0.77      0.97      0.86        38
#
#     accuracy                           0.81        64
#    macro avg       0.85      0.78      0.79        64
# weighted avg       0.84      0.81      0.80        64
#
# Accuracy: 0.81
#
# -----------------------------------------------------------
#
# Do not track
# 8
# error
#
# -----------------------------------------------------------
#
# Children's policy
# 51
# error
#
# -----------------------------------------------------------
#
# Third party sites
# 211
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        39
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.91        43
#    macro avg       0.45      0.50      0.48        43
# weighted avg       0.82      0.91      0.86        43
#
# Accuracy: 0.91
#
# -----------------------------------------------------------
#
# Data rights
# 357
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.86      1.00      0.93        62
#
#     accuracy                           0.86        72
#    macro avg       0.43      0.50      0.46        72
# weighted avg       0.74      0.86      0.80        72
#
# Accuracy: 0.86
#
# -----------------------------------------------------------
#
# End
# 80
# error
#
# -----------------------------------------------------------
#
# Website data
# 145
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        27
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.93        29
#    macro avg       0.47      0.50      0.48        29
# weighted avg       0.87      0.93      0.90        29
#
# Accuracy: 0.93
#
# -----------------------------------------------------------
#
# Data security
# 104
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.95        21
#    macro avg       0.48      0.50      0.49        21
# weighted avg       0.91      0.95      0.93        21
#
# Accuracy: 0.95
#
# -----------------------------------------------------------
#
# Advertising
# 79
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.94      1.00      0.97        15
#
#     accuracy                           0.94        16
#    macro avg       0.47      0.50      0.48        16
# weighted avg       0.88      0.94      0.91        16
#
# Accuracy: 0.94
#
# -----------------------------------------------------------
#
# Cookies
# 128
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89        21
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.81        26
#    macro avg       0.40      0.50      0.45        26
# weighted avg       0.65      0.81      0.72        26
#
# Accuracy: 0.81
#
# -----------------------------------------------------------
#
# Other
# 395
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        78
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99        79
#    macro avg       0.49      0.50      0.50        79
# weighted avg       0.97      0.99      0.98        79
#
# Accuracy: 0.99
#
# -----------------------------------------------------------
#
# Random
# 400
# error
#
# -----------------------------------------------------------
#
# Data sharing
# 174
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71        15
#            1       1.00      0.40      0.57        20
#
#     accuracy                           0.66        35
#    macro avg       0.78      0.70      0.64        35
# weighted avg       0.81      0.66      0.63        35
#
# Accuracy: 0.66
#
# -----------------------------------------------------------
#
# Location of processing
# 23
# error
#
# -----------------------------------------------------------
#
# Data retention
# 62
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
#
# Accuracy: 1.00
#
# -----------------------------------------------------------
#
# Legality of data processing
# 107
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.91        22
#    macro avg       0.45      0.50      0.48        22
# weighted avg       0.83      0.91      0.87        22
#
# Accuracy: 0.91
#
# -----------------------------------------------------------
#
# Contact
# 111
# error
#
# -----------------------------------------------------------
#
# Newsletter
# 14
# error
#
# -----------------------------------------------------------
#
# Other data collection
# 153
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        24
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.77        31
#    macro avg       0.39      0.50      0.44        31
# weighted avg       0.60      0.77      0.68        31
#
# Accuracy: 0.77
#
# -----------------------------------------------------------
#
# Data use
# 224
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        42
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.93        45
#    macro avg       0.47      0.50      0.48        45
# weighted avg       0.87      0.93      0.90        45
#
# Accuracy: 0.93
#
# -----------------------------------------------------------
#
# Data in other counries
# 80
# Classification Report for important:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        15
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.94        16
#    macro avg       0.47      0.50      0.48        16
# weighted avg       0.88      0.94      0.91        16
#
# Accuracy: 0.94
#
# -----------------------------------------------------------
#
# emails
# 16
# error
#
# -----------------------------------------------------------
#
# Full policy
# 1
# error
#
# -----------------------------------------------------------
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
from sklearn.metrics import f1_score

labelModel = logisticRegression(allChunks, 'label', False)

df = pd.DataFrame(allChunks)
df['important'] = df['important'].map({ True: 1, False: 0 })
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

predicted_importance = []

for text in X_test :
    predicted_identifier = labelsModel.predict([text])[0]
    
    importance_model = importanceModels.get(predicted_identifier)
    if importance_model is not None :
        importance_prediction = importanceModel.predict([text])[0]
    else :
        print(predictied_identifier)
        # importance_prediction = 0

    predicted_importance.append(importance_prediction)

# Step 3: Compute the F1 score
f1 = f1_score(y_test_importance, predicted_importance)
print(f"F1 Score for Important vs. Not Important: {f1:.2f}")

# %%
# neural network classifier

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, LSTM, GlobalAveragePooling1D, Dropout
from tensorflow.keras.utils import to_categorical

def NN(labelName) :
    df = pd.DataFrame(allChunks)
    if labelName == 'important' :
        df['important'] = df['important'].map({ True: 1, False: 0 })
        y = df[labelName]
    else :
        label_mapping = dict()
        for i, label in enumerate(labels) :
            label_mapping[label] = i
        df['label'] = df['label'].map(label_mapping)
        y = to_categorical(df['label'], num_classes=len(labels))
    
    X = df['text']

    MAX_NUM_WORDS = 100000
    MAX_SEQUENCE_LENGTH = 200

    tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token='<OOV>')
    tokenizer.fit_on_texts(X)
    X_sequences = tokenizer.texts_to_sequences(X)

    X_padded = pad_sequences(X_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post', truncating='post')
    X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)
    
    model = None
    if labelName == 'important' :
        model = Sequential([
            Embedding(input_dim=MAX_NUM_WORDS, output_dim=128),
            GlobalAveragePooling1D(),
            Dense(64, activation='relu'),
            Dropout(0.5),
            Dense(1, activation='sigmoid')
        ])
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    else :
        model = Sequential([
            Embedding(input_dim=MAX_NUM_WORDS, output_dim=128),
            GlobalAveragePooling1D(),  # Can also try GRU or a simple dense layer
            Dropout(0.5),
            Dense(64, activation='relu'),
            Dense(len(labels), activation='softmax')
        ])
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=10,
        batch_size=32,
        verbose=1
    )
    
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
    print(f'Test Accuracy: {accuracy:.2f}')
    y_pred = (model.predict(X_test) > 0.5).astype('int32')
    print('Classification Report:')
    print(classification_report(y_test, y_pred))

# NN('important')
NN('label')
# Out:
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/pandas/core/series.py:1031: RuntimeWarning: invalid value encountered in cast
#   arr = np.asarray(values, dtype=dtype)
# Epoch 1/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.1477 - loss: 3.0811 - val_accuracy: 0.2211 - val_loss: 2.8477
# Epoch 2/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.1709 - loss: 2.8437 - val_accuracy: 0.2139 - val_loss: 2.6987
# Epoch 3/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.1994 - loss: 2.6949 - val_accuracy: 0.2558 - val_loss: 2.6245
# Epoch 4/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.2146 - loss: 2.6189 - val_accuracy: 0.2847 - val_loss: 2.5799
# Epoch 5/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2508 - loss: 2.5236 - val_accuracy: 0.2977 - val_loss: 2.4892
# Epoch 6/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.2801 - loss: 2.4209 - val_accuracy: 0.3136 - val_loss: 2.4197
# Epoch 7/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.3192 - loss: 2.3519 - val_accuracy: 0.3483 - val_loss: 2.3246
# Epoch 8/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.3666 - loss: 2.2190 - val_accuracy: 0.3526 - val_loss: 2.2443
# Epoch 9/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.4074 - loss: 2.0871 - val_accuracy: 0.4220 - val_loss: 2.1131
# Epoch 10/10
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.4312 - loss: 1.9910 - val_accuracy: 0.4205 - val_loss: 2.0072
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4367 - loss: 1.9715
# Test Accuracy: 0.42
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.09      0.16        22
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00        14
#            3       0.50      0.06      0.10        53
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         8
#            6       0.00      0.00      0.00        44
#            7       0.82      0.41      0.55        75
#            8       0.00      0.00      0.00        15
#            9       1.00      0.03      0.06        30
#           10       1.00      0.06      0.11        17
#           11       0.00      0.00      0.00        15
#           12       0.80      0.19      0.31        21
#           13       0.94      0.16      0.28        97
#           14       0.79      0.75      0.77        80
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00         5
#           17       0.00      0.00      0.00        17
#           18       0.00      0.00      0.00        28
#           19       0.00      0.00      0.00        21
#           20       0.00      0.00      0.00         2
#           21       0.00      0.00      0.00        30
#           22       0.00      0.00      0.00        46
#           23       0.00      0.00      0.00        17
#           24       0.00      0.00      0.00         3
#
#    micro avg       0.80      0.17      0.28       692
#    macro avg       0.26      0.07      0.09       692
# weighted avg       0.46      0.17      0.22       692
#  samples avg       0.17      0.17      0.17       692
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/cs375/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
